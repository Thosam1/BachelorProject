# %% [markdown]
# Introduction text
# https://www.analyticsvidhya.com/blog/2018/09/reinforcement-multi-armed-bandit-scratch-python/

# %%
# libraries to import
import numpy as np
import matplotlib.pyplot as plt

# %%
# useful functions
def show_bar_plot(x_values, y_values, x_label="", y_label="", title=""):

    # Create bar plot
    plt.bar(x_values, y_values)

    # Add labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

    # Show the plot
    plt.show()
    
def show_line_plot(x_values, y_values, labels=[], x_label="", y_label="", title=""):

    # Create line chart
    for y, l in zip(y_values, labels):
        plt.plot(x_values, y, label='l')
        plt.legend(labels)

        
    # Add labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

    # Show the plot
    plt.show()

# %%
# Total number of arms
n_arms = 6

# probabilities
true_probs = np.random.rand(n_arms)
highest_prob_arm = np.argmax(true_probs)

print("The arm with the highest probability is at index : " + str(highest_prob_arm) + " \nits probability is : " + str(true_probs[highest_prob_arm]))
# Out:
# The arm with the highest probability is at index : 2
# its probability is : 0.84882063667795

# %%
initial_money = 1000
price_per_play = 0.5
reward = 1

# %%
show_bar_plot(x_values = range(len(true_probs)), y_values = true_probs, x_label="Arm index", y_label="Probability of success", title="Theoretical success rate of each arm")

# %% [markdown]
# # Strategy 1 : Explore then exploit
#
# For this, we explore by playing a 100 times each arm, then depending on which one got us the most wins, we decide to commit to it.

# %%
explore_per_arm = 100

results_all_arms = np.zeros((n_arms, explore_per_arm))


for arm_index in range(n_arms):
    results_all_arms[arm_index, :] = np.random.choice([0, 1], size=(1, explore_per_arm), p=[1-float(true_probs[arm_index]), float(true_probs[arm_index])])

# %%
cum_sum_results_all_arms = np.cumsum(results_all_arms, axis=1)

show_line_plot(x_values=range(explore_per_arm), y_values=cum_sum_results_all_arms, labels=range(n_arms), x_label="Nth play", y_label="Total number of successes", title="Number of wins per arm as we play more (explore)")

# %%
end_of_explore_results = np.sum(results_all_arms, axis=1)
end_of_explore_results
# Out:
# array([37.,  1., 93., 32.,  7., 70.])

# %%
show_bar_plot(x_values= range(len(end_of_explore_results)), y_values = end_of_explore_results, x_label="Arm index", y_label="Total number of wins", title="End of the explore step")

# %%
index_with_most_wins = np.argmax(end_of_explore_results)
print("The arm that won the most is : " + str(index_with_most_wins) + " with " + str(int(end_of_explore_results[index_with_most_wins])) + " wins.")
# Out:
# The arm that won the most is : 2 with 93 wins.

# %%
money_invested = explore_per_arm * n_arms * price_per_play
money_gained = np.sum(end_of_explore_results, axis=0)
money_diff_end_of_explore = money_gained - money_invested
money_left_end_of_explore = initial_money + money_diff_end_of_explore
print("Money invested : " + str(money_invested))
print("Money gained : " + str(money_gained))
print("Money difference at the end of explore round : " + str(money_diff_end_of_explore))
print("Money left at the end of explore round : " + str(money_left_end_of_explore))
# Out:
# Money invested : 300.0
# Money gained : 240.0
# Money difference at the end of explore round : -60.0
# Money left at the end of explore round : 940.0

# %% [markdown]
# ## Commit phase
# Hopefully, after the explore phase, we got the correct index that has the highest probability and now we can start winning in the long run.

# %%
minimum_money_left = initial_money - money_invested
minimum_plays_left = minimum_money_left / price_per_play

results_committed_arm = np.random.choice([0, 1], size=(1, int(minimum_plays_left)), p=[1-float(true_probs[index_with_most_wins]), float(true_probs[index_with_most_wins])])

results_committed_arm.shape
# Out:
# (1, 1400)

# %%
# todo regret analysis and plot

# %% [markdown]
# # Strategy 2 : Explore then exploit - by elimination
#
# In the previous strategy, we say decide initially how much we are going to play. To reduce the cost of exploring, we can enhance this strategy by eliminating the worst arm after a given number of plays so that we can avoid wasting money on the worst performing arm.

# %%
explore_per_arm = 30
n_rounds = 5

# check that n_rounds < n_arms
if n_rounds >= n_arms:
    raise Exception("Number of rounds should be strictly lesser than the number of arms")

end_of_explore_results = np.zeros((n_arms, 1))
poor_performing_arms = []

results_all_arms_all_rounds = np.zeros((n_arms, 1))
    
for i in range(n_rounds):
    
    results_all_arms = np.zeros((n_arms, explore_per_arm))
    
    for arm_index in range(n_arms):
        # doesn't exist in the poor performing list
        if poor_performing_arms.count(arm_index) == 0:
            results_all_arms[arm_index, :] = np.random.choice([0, 1], size=(1, explore_per_arm), p=[1-float(true_probs[arm_index]), float(true_probs[arm_index])])
            
    end_of_round_results = np.sum(results_all_arms, axis=1).reshape((n_arms,1))
    end_of_explore_results = end_of_explore_results + end_of_round_results
    
    index_with_least_wins = np.argsort(end_of_explore_results, axis=0)[i]
    
    print("Round " + str(i) + ", The arm that won the least is : " + str(index_with_least_wins) + " with " + str(int(end_of_explore_results[index_with_least_wins])) + " wins.")
    poor_performing_arms.append(index_with_least_wins)
    
    results_all_arms_all_rounds = np.concatenate((results_all_arms_all_rounds, results_all_arms), axis=1)

# reshape
results_all_arms_all_rounds = results_all_arms_all_rounds[:, 1:]
# Out:
# Round 0, The arm that won the least is : [1] with 1 wins.
# Round 1, The arm that won the least is : [4] with 3 wins.
# Round 2, The arm that won the least is : [3] with 15 wins.
# Round 3, The arm that won the least is : [0] with 64 wins.
# Round 4, The arm that won the least is : [5] with 114 wins.

# %%
cum_sum_results_all_arms = np.cumsum(results_all_arms_all_rounds, axis=1)

show_line_plot(x_values=range(explore_per_arm*n_rounds), y_values=cum_sum_results_all_arms, labels=range(n_arms), x_label="Nth play", y_label="Total number of successes", title="Number of wins per arm as we play more (explore)")

# %%
end_of_explore_results
# Out:
# array([[ 64.],
#        [  1.],
#        [125.],
#        [ 15.],
#        [  3.],
#        [114.]])

# %%
show_bar_plot(x_values = range(len(end_of_explore_results.ravel())), y_values = end_of_explore_results.ravel(), x_label="Arm index", y_label="Total number of wins", title="End of the explore step")

# %%
index_with_most_wins = np.argmax(end_of_explore_results)
print("The arm that won the most is : " + str(index_with_most_wins) + " with " + str(int(end_of_explore_results[index_with_most_wins])) + " wins.")
# Out:
# The arm that won the most is : 2 with 125 wins.

# %%
money_invested = 0
for i in range(n_rounds):
    money_invested = money_invested + explore_per_arm * (n_arms - i) * price_per_play
    
money_gained = np.sum(end_of_explore_results, axis=0)
money_diff_end_of_explore = money_gained - money_invested
money_left_end_of_explore = initial_money + money_diff_end_of_explore
print("Money invested : " + str(money_invested))
print("Money gained : " + str(money_gained))
print("Money difference at the end of explore round : " + str(money_diff_end_of_explore))
print("Money left at the end of explore round : " + str(money_left_end_of_explore))
# Out:
# Money invested : 300.0
# Money gained : [322.]
# Money difference at the end of explore round : [22.]
# Money left at the end of explore round : [1022.]

# %% [markdown]
# # Strategy 3 : Epsilon-Greedy Algorithm
#
# In the previous strategy, we say decide initially how much we are going to play. This can become a problem in situations where we have limited resources.
# A strategy would be to assign weights to each arm and recalculate every time we try one.
#
# The epsilon-greedy algorithm is a simple algorithm for exploring and exploiting a set of options or actions in a reinforcement learning problem or a multi-armed bandit problem. The algorithm works as follows:
#
# 1. Initialize a set of action-value estimates Q(a) for each action a.
#
# 2. For each time step t:
#
#     a. With probability epsilon, select a random action.
#
#     b. Otherwise, select the action with the highest action-value estimate.
#
#     c. Take the selected action and observe the reward r.
#
#     d. Update the action-value estimate Q(a) for the selected action using the observed reward r.
#
# 3. Repeat step 2 for a fixed number of time steps or until convergence.

# %%
num_trials = 600
initial_money = 1000

# check we have enough money
if num_trials * price_per_play > initial_money:
    raise Exception("You don't have enough money initially !")

# %%
# Define the multi-armed bandit algorithm
def epsilon_greedy(epsilon, n_arms):
    Q = np.zeros(n_arms) # Action-value estimates
    N = np.zeros(n_arms) # Number of times each action is taken
    def policy(state):
        if np.random.rand() < epsilon:
            return np.random.choice(n_arms)
        else:
            return np.argmax(Q)
    def update(state, action, reward):
        N[action] += 1
        Q[action] += (1 / N[action]) * (reward - Q[action])
    return policy, update

# %%
# Define the regret function
def regret(actions, true_probs):
    return np.cumsum(np.max(true_probs) - true_probs[actions])

# %%
# Run the multi-armed bandit algorithm
epsilon = 0.1
policy, update = epsilon_greedy(epsilon, n_arms)

actions = [] # arm picked
rewards = [] # result of action 

for t in range(num_trials):
    action = policy(None)
    reward = np.random.binomial(1, true_probs[action])
    actions.append(action)
    rewards.append(reward)
    update(None, action, reward)

# %% [markdown]
# ## Understanding the regret

# %%
# Compute the regret
regret_vals = regret(actions, true_probs)

# %%
# Plot the regret
plt.plot(regret_vals)
plt.xlabel('Time')
plt.ylabel('Regret')
plt.title('Epsilon-Greedy Multi-Armed Bandit Regret')
plt.show()

# %%
# Calculating money
money_invested = num_trials * price_per_play
money_gained = np.sum(rewards) * reward

money_diff_end_of_trials = money_gained - money_invested
money_left_end_of_trials = initial_money + money_diff_end_of_trials

print("Money initially : " + str(initial_money))
print("Money invested : " + str(money_invested))
print("Money gained : " + str(money_gained))
print("Money difference at the end of trials : " + str(money_diff_end_of_trials))
print("Money left at the end of trials : " + str(money_left_end_of_trials))
# Out:
# Money initially : 1000
# Money invested : 300.0
# Money gained : 468
# Money difference at the end of trials : 168.0
# Money left at the end of trials : 1168.0

# %%
rewards_array = np.array(rewards).reshape((1, num_trials))
cum_sum_rewards = np.cumsum(rewards_array, axis=1)
show_line_plot(x_values=range(num_trials), y_values=cum_sum_rewards, labels=[""], x_label="Nth trial", y_label="number of successes", title="Total number of successes")

# %%
optimal_arm = np.argmax(true_probs)

sub_optimal_arm_chosen = np.cumsum((actions != optimal_arm).astype(int))

plt.plot(sub_optimal_arm_chosen)
plt.xlabel('Time')
plt.ylabel('Total nb of times sub-optimal arm was chosen')
plt.title('# times sub-optimal arm was chosen')
plt.show()

# %%
optimal_arm_chosen = np.cumsum((actions == optimal_arm).astype(int))

optimal_arm_chosen

plt.plot(optimal_arm_chosen)
plt.xlabel('Time')
plt.ylabel('Total nb of times optimal arm was chosen')
plt.title('# times optimal arm was chosen')
plt.show()

# %% [markdown]
# # Strategy 4 : Explore then exploit

# %%
# variables
c = 1

# %%
def elimination_confidence_bound_algorithm(n_arms, n_steps, c, p):
    # Initialize variables
    wins = np.zeros(n_arms)
    losses = np.zeros(n_arms)
    upper_bounds = np.ones(n_arms) * float('inf')
    lower_bounds = np.ones(n_arms) * float('-inf')
    selected_arms = []
    rewards = []
    eliminated_arms = []
    
    for step in range(n_steps):
        # Calculate upper confidence bounds for each arm
        for i in range(n_arms):
            if eliminated_arms.count(i) == 0:
                if wins[i] + losses[i] > 0:
                    p_i = wins[i] / (wins[i] + losses[i])
                    upper_bounds[i] = p_i + c / np.sqrt(wins[i] + losses[i])
                    lower_bounds[i] = p_i - c / np.sqrt(wins[i] + losses[i])
        
        # Select arm with highest upper confidence bound
        selected_arm = np.argmax(upper_bounds)
        selected_arms.append(selected_arm)
        
        # Simulate play and update wins and losses
        if np.random.rand() < p[selected_arm]:  # simulate win with probability p_i
            wins[selected_arm] += 1
            rewards.append(1)
        else:
            losses[selected_arm] += 1
            rewards.append(0)

        # Check to eliminate arm
        for i in range(n_arms):
            if eliminated_arms.count(i) == 0:
                if i != selected_arm and upper_bounds[i] < lower_bounds[selected_arm]:    
                    print("eliminated arm : " + str(i) + ", at step : " + str(step))
                    eliminated_arms.append(i)
                    upper_bounds[i] = float('-inf') 
                    lower_bounds[i] = float('-inf')
        

        # Check if there is only one arm left
        if np.sum(upper_bounds != float('-inf')) == 1:
            break
            

    # Return selected arms at each step
    return selected_arms, rewards, wins, losses

# %%
selected_arms, rewards, wins, losses = elimination_confidence_bound_algorithm(n_arms, 9000, c, true_probs)
# Out:
# eliminated arm : 0, at step : 78
# eliminated arm : 1, at step : 78
# eliminated arm : 3, at step : 78
# eliminated arm : 4, at step : 78

# %%
def plot_estimate_interval(n_arms, wins, losses, c):
    # Calculate upper and lower confidence bounds for each arm
    p = np.zeros(n_arms)
    lower_bounds = np.zeros(n_arms)
    upper_bounds = np.zeros(n_arms)
    for i in range(n_arms):
        if wins[i] + losses[i] > 0:
            p[i] = wins[i] / (wins[i] + losses[i])
            lower_bounds[i] = p[i] - c / np.sqrt(wins[i] + losses[i])
            upper_bounds[i] = p[i] + c / np.sqrt(wins[i] + losses[i])
        else:
            p[i] = 0
            lower_bounds[i] = 0
            upper_bounds[i] = 0
    
    # Plot bar plot with estimate interval
    x = np.arange(n_arms)
    fig, ax = plt.subplots()
    ax.bar(x, p, align='center', alpha=0.5)
    ax.vlines(x, lower_bounds, upper_bounds, colors='r', linewidth=2)
    ax.set_xlabel('Arm')
    ax.set_ylabel('Probability Estimate')
    ax.set_title('Estimate Interval')
    plt.show()

# %%
plot_estimate_interval(n_arms, wins, losses, c)

# %%
# Compute the regret
regret_vals = regret(selected_arms, true_probs)

# Plot the regret
plt.plot(regret_vals)
plt.xlabel('Time')
plt.ylabel('Regret')
plt.title('Confidence Bound Elimination Multi-Armed Bandit Regret')
plt.show()

# %%
optimal_arm = np.argmax(true_probs)

sub_optimal_arm_chosen = np.cumsum((actions != optimal_arm).astype(int))

plt.plot(sub_optimal_arm_chosen)
plt.xlabel('Time')
plt.ylabel('Total nb of times sub-optimal arm was chosen')
plt.title('# times sub-optimal arm was chosen')
plt.show()
